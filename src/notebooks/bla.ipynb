# %%
from enums.Participant import NurseParticipant
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from enums.Dataset import Dataset
from model.XGBoostModel import XGBoostModel
from utils import utils

dataset = Dataset.NURSE

# %%
df = utils.load_data(dataset=dataset, which="all", with_features=False)

# %%
# shuffle the data
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
train = df[df["Participant"] != NurseParticipant.n_DF.value]
test = df[df["Participant"] == NurseParticipant.n_DF.value]
groups = train["Participant"]
x_train = train.drop(columns=["Participant", "Label"])
y_train = train["Label"]
x_test = test.drop(columns=["Participant", "Label"])
y_test = test["Label"]

# %%
model = XGBoostModel(scaler=None, resampler=None, dataset=dataset, with_features=False)

# %%
model.fit(x_train=x_train, y_train=y_train, groups=groups, run_info={})
# Out:
# Fitting 12 folds for each of 5 candidates, totalling 60 fits
# [CV] END ...................................clf__max_depth=4; total time= 2.3min
# [CV] END ...................................clf__max_depth=4; total time= 1.6min
# [CV] END ...................................clf__max_depth=6; total time= 2.7min
# [CV] END ...................................clf__max_depth=8; total time= 2.6min
# [CV] END ...................................clf__max_depth=8; total time= 2.2min
# [CV] END ..................................clf__max_depth=10; total time= 2.4min
# [CV] END ..................................clf__max_depth=12; total time= 3.5min
# [CV] END ..................................clf__max_depth=12; total time= 2.2min
# [CV] END ...................................clf__max_depth=4; total time= 2.7min
# [CV] END ...................................clf__max_depth=4; total time= 2.6min
# [CV] END ...................................clf__max_depth=6; total time= 2.4min
# [CV] END ...................................clf__max_depth=8; total time= 2.3min
# [CV] END ...................................clf__max_depth=8; total time= 1.8min
# [CV] END ..................................clf__max_depth=10; total time= 2.9min
# [CV] END ..................................clf__max_depth=12; total time= 3.7min
# [CV] END ..................................clf__max_depth=12; total time= 1.5min
# [CV] END ...................................clf__max_depth=4; total time= 2.1min
# [CV] END ...................................clf__max_depth=4; total time= 2.0min
# [CV] END ...................................clf__max_depth=6; total time= 3.3min
# [CV] END ...................................clf__max_depth=8; total time= 2.6min
# [CV] END ...................................clf__max_depth=8; total time= 2.4min
# [CV] END ..................................clf__max_depth=10; total time= 2.4min
# [CV] END ..................................clf__max_depth=12; total time= 3.6min
# [CV] END ..................................clf__max_depth=12; total time= 1.4min

# %%
pred_train = model.predict(x=x_train)
scores_train, _ = model.evaluate(pred=pred_train, y_true=y_train)
pred_test = model.predict(x=x_test)
scores_test, cm = model.evaluate(pred=pred_test, y_true=y_test)

print(scores_train)
print(scores_test)
# Out:
# {'accuracy': 0.8751499295493497, 'recall': 0.882048070012088, 'precision': 0.9679213881872778, 'f1': 0.9229916619326187, 'confusion_matrix': {'tp': 6911644, 'tn': 1172704, 'fp': 924260, 'fn': 229064}}
# {'accuracy': 0.7775962156781565, 'recall': 0.916165160633443, 'precision': 0.8369577855131062, 'f1': 0.874772149544299, 'confusion_matrix': {'tp': 705460, 'tn': 728, 'fp': 64554, 'fn': 137426}}
