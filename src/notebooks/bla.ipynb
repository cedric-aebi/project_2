# %%
from enums.Participant import NurseParticipant, StressParticipant
from model.ShallowNNModel import ShallowNNModel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from enums.Dataset import Dataset
from model.XGBoostModel import XGBoostModel
from utils import utils

dataset = Dataset.STRESS

# %%
df = utils.load_data(dataset=dataset, which=StressParticipant.s_2, with_features=True)

# %%
from enums.Model import Model

x_train, x_val, x_test, y_train, y_val, y_test = utils.split_data(
    df=df, with_features=True, model=Model.XGBOOST
)

# %%
model = XGBoostModel(scaler=None, resampler=None, dataset=dataset, with_features=True)

# %%
model.fit(x_train=x_train, y_train=y_train, run_info={})

# %%
pred_train = model.predict(x=x_train)
scores_train, _ = model.evaluate(pred=pred_train, y_true=y_train)
pred_test = model.predict(x=x_test)
scores_test, cm = model.evaluate(pred=pred_test, y_true=y_test)

print(scores_train)
print(scores_test)
# Out:
# {'accuracy': 1.0, 'recall': 1.0, 'precision': 1.0, 'f1': 1.0, 'confusion_matrix': {'tp': 196, 'tn': 221, 'fp': 0, 'fn': 0}}
# {'accuracy': 0.5019455252918288, 'recall': 0.018018018018018018, 'precision': 0.09523809523809523, 'f1': 0.030303030303030304, 'confusion_matrix': {'tp': 2, 'tn': 127, 'fp': 109, 'fn': 19}}
